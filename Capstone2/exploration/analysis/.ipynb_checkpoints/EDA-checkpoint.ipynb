# %%
import numpy as np
import pandas as pd
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('../data/data_clean.csv')
df.head()
# Out:
#    Unnamed: 0          names    pictures               loc        time  \
# 0           0  000ecstaSY000   75820.jpg    Surat, Gujarat  2011-07-09
# 1           1  000ecstaSY000   75818.jpg    Surat, Gujarat  2012-08-04
# 2           2         0011zm  129462.jpg  Ontario, Ontario  2013-04-15
# 3           3         0011zm  129468.jpg  Ontario, Ontario  2010-04-22
# 4           4         0011zm  129454.jpg  Ontario, Ontario  2014-07-30
#
#     style_0 style_1 style_2  tags_0    tags_1    tags_2 tags_3 tags_4 tags_5  \
# 0  romantic    fall     NaN   puple     boots       NaN    NaN    NaN    NaN
# 1      chic   beach  summer  maroon  bracelet       NaN    NaN    NaN    NaN
# 2     urban  spring     NaN   boots    jacket  leggings  shirt    NaN    NaN
# 3   vintage  spring     NaN     hat       bag       NaN    NaN    NaN    NaN
# 4   leather   other  summer   shirt       bra     pants    NaN    NaN    NaN
#
#   tags_6 tags_7 tags_8 tags_9
# 0    NaN    NaN    NaN    NaN
# 1    NaN    NaN    NaN    NaN
# 2    NaN    NaN    NaN    NaN
# 3    NaN    NaN    NaN    NaN
# 4    NaN    NaN    NaN    NaN

# %%
location = df.groupby('loc')
location.describe().head()
# Out:
#                         Unnamed: 0                                         \
#                              count           mean           std       min
# loc
# ((..NY..))                     1.0  103069.000000           NaN  103069.0
# -, -                           4.0  147147.000000  84784.464383   73721.0
# -, France                    112.0  119613.223214  73412.314984   47795.0
# --- - Angono, Rizal          109.0  238332.660550  70976.226574  143662.0
# --- - Calgary , Alberta       63.0   82977.682540  76443.775112   16588.0
#
#
#                                25%       50%        75%       max
# loc
# ((..NY..))               103069.00  103069.0  103069.00  103069.0
# -, -                      73721.75  147147.0  220572.25  220573.0
# -, France                 47822.75   47850.5  194013.25  194041.0
# --- - Angono, Rizal      143689.00  291047.0  291075.00  291103.0
# --- - Calgary , Alberta   16603.50   16619.0  162406.50  285512.0

# %%
user = df.groupby('names')
user.describe().head()
# Out:
#               Unnamed: 0                                                   \
#                    count           mean           std      min        25%
# names
# 000ecstaSY000        3.0   48560.333333  84108.098542      0.0       0.50
# 0011zm              24.0   91057.250000  72044.899697      2.0       7.75
# 01foreverlove      297.0  137512.838384  76864.670056   3878.0   56644.00
# 08willsters         30.0  168204.266667  67064.560473  43510.0  122435.00
# 0910beh             30.0   72862.500000  74086.744179     14.0      21.25
#
#
#                     50%        75%       max
# names
# 000ecstaSY000       1.0   72840.50  145680.0
# 0011zm         145683.5  145689.25  145695.0
# 01foreverlove  158954.0  188912.00  282191.0
# 08willsters    168086.5  217388.50  273064.0
# 0910beh         72862.5  145703.75  145711.0

# %%
location['loc'].value_counts().plot()
plt.xticks(rotation = 45)
plt.xlabel('Locations')
plt.ylabel('Number of Uploads')
plt.show()

# %%
user['names'].value_counts().plot()
plt.xticks(rotation = 45)
plt.xlabel('Users')
plt.ylabel('Number of Uploads')
plt.show()

# %%
#deal with tags later, just work on styles
#wordsTags = ' '
#for index, row in df.iterrows():
#    word0 = row['tags_0']
#    if word0 != None:
#        wordsTags = wordsTags + str(word0) + ' '
#    word1 = row['tags_1']
#    if word1 != None:
#        wordsTags = wordsTags + str(word1) + ' '
#    word2 = row['tags_2']
#    if word2 != None:
#        wordsTags = wordsTags + str(word2) + ' '
#    word3 = row['tags_3']
#    if word3 != None:
#        wordsTags = wordsTags + str(word3) + ' '
#    word4 = row['tags_4']
#    if word4 != None:
#        wordsTags = wordsTags + str(word4) + ' '
        
#wordcloudTags = WordCloud(width = 800, height = 800, 
#                background_color ='black', collocations = False).generate(wordsTags)

#plt.imshow(wordcloudTags, iterpolation = 'bilinear')
#plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-294a64a9416d> in <module>()
#      16     word4 = row['tags_4']
#      17     if word4 != None:
# ---> 18         words = words + str(word4) + ' '
#      19
#      20 wordcloud = WordCloud().generate(words)
#
# KeyboardInterrupt:

# %%
wordsStyles = ' '
for index, row in df.iterrows():
    word0 = row['style_0']
    if (word0 != None) and (word0 != 'nan'):
        wordsStyles = wordsStyles + str(word0) + ' '
    word1 = row['style_1']
    if (word1 != None) and (word1 != 'nan'):
        wordsStyles = wordsStyles + str(word1) + ' '
    word2 = row['style_2']
    if (word2 != None) and (word2 != 'nan'):
        wordsStyles = wordsStyles + str(word2) + ' '
        
wordcloudStyles = WordCloud(width = 800, height = 800, 
                background_color ='black', collocations = False).generate(wordsStyles)

# %%
plt.imshow(wordcloudStyles)
plt.show()

# %%
#histogram of word frequencies

# %%
from collections import Counter

styleCounts = dict(Counter(wordsStyles.split()).most_common(20))
print(styleCounts)
styleUnique, styleCounts = zip(*styleCounts.items())

plt.bar(styleUnique, styleCounts)
plt.xticks(styleUnique, rotation = 45)
# Out:
# {'winter': 18765, 'everyday': 58465, 'basic': 4992, 'summer': 56616, 'nan': 57828, 'bohemian': 6736, 'spring': 37869, 'trendy': 8584, 'brunch': 6146, 'comfortable': 7685, 'casual': 24832, 'vintage': 5345, 'work': 6559, 'fall': 37290, 'classic': 6431, 'chic': 30043, 'urban': 4691, 'eclectic': 4023, 'romantic': 6195, 'elegant': 4639}
# ([<matplotlib.axis.XTick at 0x7f5c44b84710>,
#   <matplotlib.axis.XTick at 0x7f5c44b84198>,
#   <matplotlib.axis.XTick at 0x7f5c44b83da0>,
#   <matplotlib.axis.XTick at 0x7f5c45f9e0f0>,
#   <matplotlib.axis.XTick at 0x7f5c45f9e550>,
#   <matplotlib.axis.XTick at 0x7f5c45f9ea58>,
#   <matplotlib.axis.XTick at 0x7f5c45f9ef60>,
#   <matplotlib.axis.XTick at 0x7f5c45fa24a8>,
#   <matplotlib.axis.XTick at 0x7f5c45fa29b0>,
#   <matplotlib.axis.XTick at 0x7f5c45f9e1d0>,
#   <matplotlib.axis.XTick at 0x7f5c45fa26d8>,
#   <matplotlib.axis.XTick at 0x7f5c45fae160>,
#   <matplotlib.axis.XTick at 0x7f5c45fae630>,
#   <matplotlib.axis.XTick at 0x7f5c45faeb38>,
#   <matplotlib.axis.XTick at 0x7f5c45fac0f0>,
#   <matplotlib.axis.XTick at 0x7f5c45fac588>,
#   <matplotlib.axis.XTick at 0x7f5c45faca90>,
#   <matplotlib.axis.XTick at 0x7f5c45face80>,
#   <matplotlib.axis.XTick at 0x7f5c45faca58>,
#   <matplotlib.axis.XTick at 0x7f5c45fae4a8>],
#  <a list of 20 Text xticklabel objects>)

# %%
#time data - look at range of dates
#plot dates against word frequencies over time
#word cloud changing by year?
print(df['time'].min())
print(df['time'].max())
# Out:
# 2008-03-02
# 2015-12-15

# %%
#create dataframes for each year:
data_2008 = df[(df['time'] < '2009-01-01')]
data_2009 = df[(df['time'] >= '2009-01-01') & (df['time'] < '2010-01-01')]
data_2010 = df[(df['time'] >= '2010-01-01') & (df['time'] < '2011-01-01')]
data_2011 = df[(df['time'] >= '2011-01-01') & (df['time'] < '2012-01-01')]
data_2012 = df[(df['time'] >= '2012-01-01') & (df['time'] < '2013-01-01')]
data_2013 = df[(df['time'] >= '2013-01-01') & (df['time'] < '2014-01-01')]
data_2014 = df[(df['time'] >= '2014-01-01') & (df['time'] < '2015-01-01')]
data_2015 = df[(df['time'] >= '2015-01-01')]

# %%
entries = [data_2008['names'].count(), data_2009['names'].count(), data_2010['names'].count()
          , data_2011['names'].count(), data_2012['names'].count(), data_2013['names'].count()
          , data_2014['names'].count(), data_2015['names'].count()]

plt.plot(entries)
plt.xticks([0,1,2,3,4,5,6,7], [2008,2009,2010,2011,2012,2013,2014,2015], rotation = 45)
# Out:
# ([<matplotlib.axis.XTick at 0x7f5c444bf438>,
#   <matplotlib.axis.XTick at 0x7f5c444bfc50>,
#   <matplotlib.axis.XTick at 0x7f5c444bf6a0>,
#   <matplotlib.axis.XTick at 0x7f5c4656f358>,
#   <matplotlib.axis.XTick at 0x7f5c4656ff60>,
#   <matplotlib.axis.XTick at 0x7f5c45ef0d68>,
#   <matplotlib.axis.XTick at 0x7f5c45ef0668>,
#   <matplotlib.axis.XTick at 0x7f5c45ef0cf8>],
#  <a list of 8 Text xticklabel objects>)

# %%
def styleWordCloud(dataframe):
    styleWords = ' '
    for index, row in dataframe.iterrows():
        word0 = row['style_0']
        if (word0 != None) and (word0 != 'nan'):
            styleWords = styleWords + str(word0) + ' '
        word1 = row['style_1']
        if (word1 != None) and (word1 != 'nan'):
            styleWords = styleWords + str(word1) + ' '
        word2 = row['style_2']
        if (word2 != None) and (word2 != 'nan'):
            styleWords = styleWords + str(word2) + ' '
    
    wcStyles = WordCloud(width = 800, height = 800, 
                background_color ='black', collocations = False).generate(styleWords)
    plt.imshow(wcStyles)
    plt.show()
    return styleWords

def getStyles(dataframe):
    styleWords = ' '
    for index, row in dataframe.iterrows():
        word0 = row['style_0']
        if (word0 != None) and (word0 != 'nan'):
            styleWords = styleWords + str(word0) + ' '
        word1 = row['style_1']
        if (word1 != None) and (word1 != 'nan'):
            styleWords = styleWords + str(word1) + ' '
        word2 = row['style_2']
        if (word2 != None) and (word2 != 'nan'):
            styleWords = styleWords + str(word2) + ' '
    
    return styleWords

def plotWordFreq(words):
    styleCounts = dict(Counter(words.split()).most_common(20))
    styleUnique, styleCounts = zip(*styleCounts.items())
    plt.bar(styleUnique, styleCounts)
    plt.xticks(styleUnique, rotation = 45)
    plt.show()
    return styleUnique, styleCounts
   
styles2008 = styleWordCloud(data_2008)    
styles2009 = styleWordCloud(data_2009)    
styles2010 = styleWordCloud(data_2010)    
styles2011 = styleWordCloud(data_2011)    
styles2012 = styleWordCloud(data_2012)    
styles2013 = styleWordCloud(data_2013)    
styles2014 = styleWordCloud(data_2014)    
styles2015 = styleWordCloud(data_2015)

# %%
unique2008, freq2008 = plotWordFreq(styles2008)
unique2009, freq2009 = plotWordFreq(styles2009)
unique2010, freq2010 = plotWordFreq(styles2010)
unique2011, freq2011 = plotWordFreq(styles2011)
unique2012, freq2012 = plotWordFreq(styles2012)
unique2013, freq2013 = plotWordFreq(styles2013)
unique2014, freq2014 = plotWordFreq(styles2014)
unique2015, freq2015 = plotWordFreq(styles2015)
#use bokeh slider for this
#bokeh drop down menu to go between the different common words

# %%
yearlyFreqs = pd.DataFrame()
yearlyFreqs['2008'] = freq2008[0:10]
yearlyFreqs['2009'] = freq2009[0:10]
yearlyFreqs['2010'] = freq2010[0:10]
yearlyFreqs['2011'] = freq2011[0:10]
yearlyFreqs['2012'] = freq2012[0:10]
yearlyFreqs['2013'] = freq2013[0:10]
yearlyFreqs['2014'] = freq2014[0:10]
yearlyFreqs['2015'] = freq2015[0:10]
yearlyFreqs['labels'] = unique2008[0:10]

totals = []
for item, row in yearlyFreqs.iterrows():
    totals.append(row['2008']+row['2009']+row['2010']+row['2011']
    +row['2012']+row['2013']+row['2014']+row['2015'])

yearlyFreqs['totals'] = totals

yearlyFreqs
# Out:
#    2008  2009   2010   2011   2012   2013   2014   2015       labels  totals
# 0   566  1639   3550   5333   7308   7364   5789   2768       winter   34317
# 1   216  5157  11094  17324  23503  23071  18196   8575  comfortable  107136
# 2   103   424    884   1503   2089   1931   1492    664        basic    9090
# 3  1378  4611  10191  16249  22682  22280  17997   8430       summer  103818
# 4  1941  6138  13105  20627  28481  27045  22923  10794          nan  131054
# 5   166   525   1201   1874   2669   2673   2166    945     bohemian   12219
# 6   111   320   7099  10881  14967  14734  11827   5481     shopping   65420
# 7   914  3315   1577   2476   3621   3439   2644   1226       spring   19212
# 8  1516   735   1185   1740   2460   2357   1891    900     everyday   12784
# 9   147   539   1434   2210   2933   2921   2396   1081       brunch   13661

# %%
for i in range(0,10):
    plt.plot(yearlyFreqs.loc[i][0:8])
    plt.title(yearlyFreqs.loc[i][8])
    plt.show()

# %%
#subtract usage curve to normalize 
entriesNorm = entries/df['names'].count()

for i in range(0,10):
    plt.plot((yearlyFreqs.loc[i][0:8]/yearlyFreqs.loc[i][9]) - entriesNorm)
    plt.title(yearlyFreqs.loc[i][8])
    plt.show()

# %%
#make sure to use bokeh

# %%
def getWordFreq(words):
    styleCounts = dict(Counter(words.split()).most_common(20))
    styleUnique, styleCounts = zip(*styleCounts.items())
    return styleUnique, styleCounts

from bokeh.io import output_notebook
from bokeh.layouts import row, column, widgetbox
from bokeh.models import ColumnDataSource, CustomJS
from bokeh.models.widgets import Slider, TextInput
from bokeh.plotting import figure, show

output_notebook()

# Set up data
N = 200
x, y = getWordFreq(styles2008)
source = ColumnDataSource(data=dict(x=x, y=y))


# Set up plot
plot = figure(plot_height=400, plot_width=400, title="Popular Styles Over Time",
              tools="crosshair,pan,reset,save,wheel_zoom",
              x_range=x, y_range=[0, 6000])
plot.vbar('x', top = 'y', source=source, width=0.5)


# Set up widgets
text = TextInput(title="title", value='date')
slider = Slider(title="date", value=2008, start=2008, end=2015, step=1)

# Set up callbacks
def update_title(attrname, old, new):
    plot.title.text = text.value

text.on_change('value', update_title)

update_data = CustomJS(args=dict(source=source, slider=slider), code = """
    var data = source.data;
    var f = slider.value;
    x, y = getWordFreq(styles+f)
    source.change.emit();
""")

for w in [date]:
    w.js_on_change('value', update_data)

# Set up layouts and add to document
inputs = widgetbox(text, date)
layout = row(plot,widgetbox(text, date))

#curdoc().add_root(row(inputs, layout, width=800))
#curdoc().title = "Sliders"

show(column(slider, plot))
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="df0ecfd5-86f4-45df-952b-fefa2e96b94a">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="1e5e69d0-fc72-4daf-bc9c-2fd0231035c2"></div>
# </div>

# %%
# plot word popularity by month
#unique2012, freq2012 = plotWordFreq(styles2012)
#data_2012
#split by months
data_2012['time'] = pd.to_datetime(data_2012['time'])
months = [g for n, g in data_2012.groupby(pd.Grouper(key='time',freq='M'))]
print(months[2])
# Out:
#         Unnamed: 0                names    pictures  \
# 886            903      365beautywishes   98117.jpg
# 1495          1525           AbethaAnne  135833.jpg
# 5714          5797             iamalexa   48790.jpg
# 6093          6176              alexm92  103112.jpg
# 6689          6772       lavagrantbelle   86207.jpg
# 7348          7440    allyouneedisstyle  145488.jpg
# 13259        13518             Annebeth   13274.jpg
# 16410        16696             AsterJin  162780.jpg
# 25265        25946           candy_ytal  230042.jpg
# 25787        26468                CaraJ   20871.jpg
# 26161        26843          carizzachua    7881.jpg
# 33516        34401           CoffeBreak  203947.jpg
# 38352        39277          demidonohoe  223752.jpg
# 39723        40651     disarmingdarling   82955.jpg
# 40235        41164       districtofchic    8656.jpg
# 41390        42425        BERTHANATASHA  120594.jpg
# 42620        43657            EditaOmar   49231.jpg
# 44548        45677        elodieinparis  118778.jpg
# 45415        46544           Emmasdiary  209956.jpg
# 45876        47005            emykoster  275716.jpg
# 46417        47553              esencja  226943.jpg
# 46789        47925         estiloenruta  107230.jpg
# 47074        48213    EverydayForgotten  201822.jpg
# 47790        48958              famoody  203166.jpg
# 48485        49654         FashionAgony   81737.jpg
# 49720        50925        fashionhippie   87083.jpg
# 54218        55568             flattery  207046.jpg
# 56657        58023  girlnextdoorfashion  120968.jpg
# 58573        59973       grasiemercedes  203555.jpg
# 58700        60100            grayskies  138180.jpg
# ...            ...                  ...         ...
# 201736      207719               Hantsa   23806.jpg
# 204579      210614        huynhmichelle  104831.jpg
# 204826      210917            IamDanica  111789.jpg
# 205758      211943             imisshsu  229353.jpg
# 214819      221502        justlikesushi  163530.jpg
# 214919      221603            JustWeeJo  178087.jpg
# 215200      221898        TheSkirtedBoy   97932.jpg
# 216836      223563         katrinaelena  282535.jpg
# 217599      224353         editorspicks  136478.jpg
# 229343      236637  lulut_marganingtyas   26436.jpg
# 232177      239621              Marella  117677.jpg
# 232921      240382             Mariavia   64034.jpg
# 233860      241349             Maryleen   97619.jpg
# 236989      244527             mestizay  137799.jpg
# 238233      245792  MidwesternButterfly  198080.jpg
# 240930      248623            modishYou  172449.jpg
# 246550      254497            NoraFinds   73102.jpg
# 249002      257012      parachutepantsZ    9714.jpg
# 250304      258337             phani128    9753.jpg
# 250330      258364             phani128    9756.jpg
# 250528      258564              barbali   94033.jpg
# 261540      269814           IreneGreen  263166.jpg
# 262837      271133              slicari   41723.jpg
# 268432      276885              barbali   93424.jpg
# 270180      278668                Teal6  131247.jpg
# 276885      285632           uniqueELLE  131442.jpg
# 277339      286092      valeriecaroline  231278.jpg
# 278233      286997      LipstickLesbian  229057.jpg
# 278607      287378              barbali   91066.jpg
# 283859      292739          Mrscarlasia    5124.jpg
#
#                                    loc       time      style_0   style_1  \
# 886                     Washington, DC 2012-03-01         chic    spring
# 1495                  Philadelphia, PA 2012-03-01      vintage      fall
# 5714        Cebu City, Central Visayas 2012-03-01         chic  everyday
# 6093    West Yorkshire, United Kingdom 2012-03-01       casual  everyday
# 6689      United States, United States 2012-03-01       casual    spring
# 7348                    Athens, Attiki 2012-03-01         chic    summer
# 13259               Antwerpen, Belgium 2012-03-01          50s    summer
# 16410               Malaysia, Malaysia 2012-03-01     romantic    spring
# 25265                Cebu, Philippines 2012-03-01       casual    summer
# 25787                 Vancouver Canada 2012-03-01         goth      fall
# 26161                      Philippines 2012-03-01         chic    brunch
# 33516                      Rome, Italy 2012-03-01     bohemian    summer
# 38352                      England, UK 2012-03-01       casual  shopping
# 39723                  Los Angeles, CA 2012-03-01      vintage      fall
# 40235                   Washington, DC 2012-03-01      classic    summer
# 41390               Jakarta, Indonesia 2012-03-01        basic      work
# 42620                 Leipzig, Germany 2012-03-01       casual  everyday
# 44548                    Paris, France 2012-03-01       casual      work
# 45415                           France 2012-03-01     bohemian  everyday
# 45876           Rotterdam, Netherlands 2012-03-01      classic    spring
# 46417                    Murcia, Spain 2012-03-01      elegant  everyday
# 46789                    Madrid, Spain 2012-03-01  comfortable  everyday
# 47074          England, United Kingdom 2012-03-01         chic  everyday
# 47790                Bydgoszcz, Poland 2012-03-01     romantic  cocktail
# 48485                          Ukraine 2012-03-01     romantic  clubbing
# 49720     Stuttgart, Baden Wurttemberg 2012-03-01         chic      work
# 54218       Winnipeg, Manitoba, Canada 2012-03-01         chic      fall
# 56657              Seaside Heights, NJ 2012-03-01        urban    summer
# 58573               New York City , NY 2012-03-01      elegant    summer
# 58700                     Portland, OR 2012-03-01         chic    summer
# ...                                ...        ...          ...       ...
# 201736  Antananarivo(city), Madagascar 2012-03-31      vintage  everyday
# 204579               Orange County, CA 2012-03-31          80s    summer
# 204826               Naga, Philippines 2012-03-31  comfortable      fall
# 205758           Batangas, Philippines 2012-03-31       casual    summer
# 214819            Groningen, Groningen 2012-03-31         chic  everyday
# 214919          London, United Kingdom 2012-03-31      vintage    brunch
# 215200              Astana, Kazakhstan 2012-03-31       school      fall
# 216836             Manila, Philippines 2012-03-31         chic      fall
# 217599                   Encinitas, CA 2012-03-31     bohemian  everyday
# 229343              Jakarta, Indonesia 2012-03-31        basic  everyday
# 232177                 Genova, Liguria 2012-03-31         chic    spring
# 232921                       Indonesia 2012-03-31       preppy  everyday
# 233860                   Amsterdam, NL 2012-03-31       casual    brunch
# 236989          Paranaque, Philippines 2012-03-31        retro    spring
# 238233                 Sioux Falls, SD 2012-03-31         chic    winter
# 240930             Warsaw, Mazowieckie 2012-03-31     shopping      fall
# 246550        Sydney , New South Wales 2012-03-31       casual  everyday
# 249002                    Hartford, CT 2012-03-31         chic    summer
# 250304                    /, Indonesia 2012-03-31        urban  everyday
# 250330                    /, Indonesia 2012-03-31        urban  everyday
# 250528                  Athens, Attiki 2012-03-31        basic  everyday
# 261540              Jakarta, Indonesia 2012-03-31      outdoor    picnic
# 262837                 Minneapolis, MN 2012-03-31         chic      work
# 268432        AMSTERDAM, NOORD-HOLLAND 2012-03-31         chic    spring
# 270180              North Bay, Ontario 2012-03-31     bohemian    spring
# 276885            Bratislava, Slovakia 2012-03-31          NaN       NaN
# 277339                     Netherlands 2012-03-31          NaN       NaN
# 278233                Barcelona, Spain 2012-03-31          NaN       NaN
# 278607                       barcelona 2012-03-31          NaN       NaN
# 283859        Quezon City, Philippines 2012-03-31          NaN       NaN
#
#        style_2       tags_0       tags_1    tags_2       tags_3      tags_4  \
# 886        NaN          toe        shoes    skinny        jeans         bow
# 1495       NaN      mustard        roses     dress       purple      opaque
# 5714      fall         pink      printed     dress        black         bag
# 6093    winter         gray     cardigan      gray        dress       brown
# 6689       NaN         navy        shirt      gray          bag       khaki
# 7348       NaN     metallic        shirt     purse          bag        lace
# 13259      NaN        dress  accessories   sandals  accessories        belt
# 16410      NaN         gray       shorts     tawny        heels       coral
# 25265      NaN         wrap     cardigan       NaN          NaN         NaN
# 25787      NaN       bolero       jacket       NaN          NaN         NaN
# 26161   summer          red       floral     dress        black       flats
# 33516      NaN        black      t-shirt       red        skirt         NaN
# 38352   winter        boots       jacket     skirt     cardigan         NaN
# 39723      NaN          red         back     dress        black      denier
# 40235      NaN        white          top    shorts        black       socks
# 41390   winter         blue        shirt     shirt        black       pants
# 42620     fall       jacket          NaN       NaN          NaN         NaN
# 44548   spring         navy      glasses    yellow     necklace       green
# 45415     fall        brown          hat      blue        denim      shorts
# 45876      NaN        dress         vest       NaN          NaN         NaN
# 46417   winter        black        boots     black          fur        coat
# 46789   summer        shirt       shorts   sandals          NaN         NaN
# 47074   spring        black       blazer     black          bag        pink
# 47790   spring        dress     bracelet       NaN          NaN         NaN
# 48485   winter        beige      flapper     dress          NaN         NaN
# 49720   spring          red        capri  leggings         blue        roxy
# 54218      NaN         belt          NaN       NaN          NaN         NaN
# 56657      NaN      leather        boots   cut-out        dress       style
# 58573      NaN       blazer       tights       NaN          NaN         NaN
# 58700      NaN          bag        heels       NaN          NaN         NaN
# ...        ...          ...          ...       ...          ...         ...
# 201736  winter         coat        dress       NaN          NaN         NaN
# 204579     NaN          bag         gold     skort       shorts     crimson
# 204826     NaN        black      striped   sweater        green         bag
# 205758     NaN        white        shoes     camel          hat        blue
# 214819  winter       blazer         belt   striped      t-shirt        camo
# 214919  winter        ivory      booties     shoes      neutral      clutch
# 215200     NaN        white       blazer     black        pants         NaN
# 216836     NaN        brown        boots       NaN          NaN         NaN
# 217599  summer       bronze        boots     boots        white        lace
# 229343    fall        black         coat     black          bag  periwinkle
# 232177     NaN        white        dress     black        heels       black
# 232921    fall         gray        suede     shoes         gray    rosettes
# 233860  winter         navy        jeans      navy          top         red
# 236989     NaN          red      leather     skirt        ivory        silk
# 238233     NaN        dress       jacket       bag     cardigan         NaN
# 240930     NaN       shorts          NaN       NaN          NaN         NaN
# 246550    fall        jeans        jeans  handcuff  accessories    cardigan
# 249002     NaN         pink          top      pink        skirt      orange
# 250304  summer          bag       shorts       top        heels         NaN
# 250330  summer        shoes        jeans    jacket          NaN         NaN
# 250528  spring          bag        black   sandals        green      blouse
# 261540  winter  accessories        black  leggings        black      shorts
# 262837  summer   aquamarine        jeans    blazer        purse       heels
# 268432     NaN        black       blouse     black        pants       heels
# 270180     NaN        boots        dress       NaN          NaN         NaN
# 276885     NaN          NaN          NaN       NaN          NaN         NaN
# 277339     NaN          NaN          NaN       NaN          NaN         NaN
# 278233     NaN          NaN          NaN       NaN          NaN         NaN
# 278607     NaN          NaN          NaN       NaN          NaN         NaN
# 283859     NaN          NaN          NaN       NaN          NaN         NaN
#
#             tags_5       tags_6     tags_7     tags_8    tags_9
# 886           belt        black        top        NaN       NaN
# 1495        tights          red      sheer          a       NaN
# 5714         black        suede      heels       gold  bracelet
# 6093          belt          red  stockings      beige      ozzy
# 6689         pants        black      flats        NaN       NaN
# 7348        shorts         nude      heels        NaN       NaN
# 13259          NaN          NaN        NaN        NaN       NaN
# 16410     cardigan   periwinkle     modclo        NaN       NaN
# 25265          NaN          NaN        NaN        NaN       NaN
# 25787          NaN          NaN        NaN        NaN       NaN
# 26161          NaN          NaN        NaN        NaN       NaN
# 33516          NaN          NaN        NaN        NaN       NaN
# 38352          NaN          NaN        NaN        NaN       NaN
# 39723       tights        black        lea        NaN       NaN
# 40235        shoes          NaN        NaN        NaN       NaN
# 41390        pants          NaN        NaN        NaN       NaN
# 42620          NaN          NaN        NaN        NaN       NaN
# 44548     poshmark         vest       ruby        NaN       NaN
# 45415        brown     cardigan       blue      denim    blouse
# 45876          NaN          NaN        NaN        NaN       NaN
# 46417         teal        jeans      black        bag      gray
# 46789          NaN          NaN        NaN        NaN       NaN
# 47074       shorts      mustard     blouse      black     mande
# 47790          NaN          NaN        NaN        NaN       NaN
# 48485          NaN          NaN        NaN        NaN       NaN
# 49720         vest          red   victoria      papri       NaN
# 54218          NaN          NaN        NaN        NaN       NaN
# 56657   sunglasses         stud   bracelet        NaN       NaN
# 58573          NaN          NaN        NaN        NaN       NaN
# 58700          NaN          NaN        NaN        NaN       NaN
# ...            ...          ...        ...        ...       ...
# 201736         NaN          NaN        NaN        NaN       NaN
# 204579  sunglasses      loafers       pink  checkered        to
# 204826       black      pleated      skirt        red      belt
# 205758       shirt        camel        bag      khaki       NaN
# 214819       pants        heels        NaN        NaN       NaN
# 214919         bag        white     collar   forever2       NaN
# 215200         NaN          NaN        NaN        NaN       NaN
# 216836         NaN          NaN        NaN        NaN       NaN
# 217599      blouse          NaN        NaN        NaN       NaN
# 229343     quilted       hoodie      black       hair    wedges
# 232177    necklace          NaN        NaN        NaN       NaN
# 232921         hat        white       flor        NaN       NaN
# 233860       pumps          NaN        NaN        NaN       NaN
# 236989      blouse          NaN        NaN        NaN       NaN
# 238233         NaN          NaN        NaN        NaN       NaN
# 240930         NaN          NaN        NaN        NaN       NaN
# 246550    cardigan         arro        NaN        NaN       NaN
# 249002       heels          gum        acc        NaN       NaN
# 250304         NaN          NaN        NaN        NaN       NaN
# 250330         NaN          NaN        NaN        NaN       NaN
# 250528         NaN          NaN        NaN        NaN       NaN
# 261540         top  accessories        NaN        NaN       NaN
# 262837      blouse         belt        NaN        NaN       NaN
# 268432         NaN          NaN        NaN        NaN       NaN
# 270180         NaN          NaN        NaN        NaN       NaN
# 276885         NaN          NaN        NaN        NaN       NaN
# 277339         NaN          NaN        NaN        NaN       NaN
# 278233         NaN          NaN        NaN        NaN       NaN
# 278607         NaN          NaN        NaN        NaN       NaN
# 283859         NaN          NaN        NaN        NaN       NaN
#
# [5329 rows x 18 columns]

# %%
def getWordFreq(words):
    styleCounts = dict(Counter(words.split()).most_common(20))
    styleUnique, styleCounts = zip(*styleCounts.items())
    return styleUnique, styleCounts

months_2012Counts = []
months_2012Styles = []
for i in range (0,11):
    months_2012Styles[i], months_2012Counts[i] = getWordFreq(months[i])
    
for i in range(0,10):
    plt.plot(months_2012Counts[i][0:8])
    plt.title(months_2012Counts[i][8])
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-161-b8c84aa4a78f> in <module>()
#       7 months_2012Styles = []
#       8 for i in range (0,11):
# ----> 9     months_2012Styles[i], months_2012Counts[i] = getWordFreq(months[i])
#      10
#      11 for i in range(0,10):
#
# <ipython-input-161-b8c84aa4a78f> in getWordFreq(words)
#       1 def getWordFreq(words):
# ----> 2     styleCounts = dict(Counter(words.split()).most_common(20))
#       3     styleUnique, styleCounts = zip(*styleCounts.items())
#       4     return styleUnique, styleCounts
#       5
#
# ~/anaconda3/lib/python3.5/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'split'
