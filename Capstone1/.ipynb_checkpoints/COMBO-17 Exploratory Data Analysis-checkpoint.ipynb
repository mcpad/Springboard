# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
from astropy.io import fits
from astropy.table import Table
from scipy.stats.stats import pearsonr
from scipy import stats

pd.set_option('display.max_columns', None)

# %%
np.random.seed(3791)

#method to use thoughout the exercise 
# From the datacamp statistical thinking in python exercises
def draw_bs_reps(data, func, size=1):
    bs_replicates = np.empty(size)
    for i in range(size):
        bs_replicates[i] = func(np.random.choice(data, size=len(data)))
    return bs_replicates

def ecdf(data):
    n = len(data)
    x = np.sort(data)
    y = np.arange(1, n+1) / n
    return x, y

# %%
# Import galaxies.csv
galaxies = pd.read_csv('galaxies.csv')

# %%
# Get the description of the galaxies dataframe
galaxies.describe()
# Out:
#                 Seq            ra           dec             x             y  \
# count  14283.000000  14283.000000  14283.000000  14283.000000  14283.000000
# mean   32031.989988     53.103185    -27.812231   3996.990690   3822.679154
# std    18067.286515      0.168712      0.144062   2257.907307   2179.420643
# min       28.000000     52.808610    -28.065162      2.755915      2.329053
# 25%    16137.000000     52.959550    -27.940175   2036.078300   1884.456550
# 50%    32464.000000     53.098921    -27.807209   4053.147200   3901.554700
# 75%    47408.500000     53.249622    -27.689810   5922.515250   5675.447500
# max    63501.000000     53.401884    -27.564573   7929.383000   7562.462000
#
#                Rmag        e_Rmag       Ap_Rmag      ApD_Rmag        mu_max  \
# count  14283.000000  14283.000000  14283.000000  14283.000000  14283.000000
# mean      22.877013      0.044602     23.299326     -0.480696     23.551996
# std        1.106667      0.026406      0.996280      0.513395      0.941022
# min       10.765173      0.000000     17.549747    -14.357697     17.722456
# 25%       22.422863      0.023800     22.842112     -0.652856     23.133142
# 50%       23.217447      0.043000     23.524193     -0.367838     23.745733
# 75%       23.680439      0.061600     23.927407     -0.173506     24.170527
# max       23.999872      0.162300     27.370026      0.774403     25.797379
#
#                MC_z        e_MC_z       MC_z_ml       chi2red         UjMag  \
# count  14283.000000  14283.000000  14283.000000  14283.000000  14283.000000
# mean       0.660716      0.096852      0.776111      1.269137    -18.515432
# std        0.328524      0.127295      0.503929      0.702048      1.923455
# min        0.002813      0.000262      0.000000      0.129306    -31.328515
# 25%        0.404561      0.025350      0.417831      0.817441    -19.743293
# 50%        0.687348      0.046710      0.705174      1.134658    -18.994874
# 75%        0.886551      0.094712      0.980389      1.554113    -17.769092
# max        1.599780      0.960147      2.883012     13.657068     -5.340054
#
#             e_UjMag         BjMag       e_BjMag         VjMag       e_VjMag  \
# count  14283.000000  14283.000000  14283.000000  14283.000000  14283.000000
# mean       0.147874    -18.469470      0.200725    -18.872764      0.217972
# std        0.587412      1.927691      1.245905      1.941073      1.004992
# min        0.100072    -31.395583      0.100037    -32.055682      0.100006
# 25%        0.106623    -19.712320      0.105233    -20.135760      0.109505
# 50%        0.117877    -18.890479      0.120750    -19.233557      0.138117
# 75%        0.139546    -17.702023      0.172391    -18.020602      0.212125
# max       65.264145     -5.250331     88.907875     -5.834827     86.272079
#
#               usMag       e_usMag         gsMag       e_gsMag         rsMag  \
# count  14283.000000  14283.000000  14283.000000  14283.000000  14283.000000
# mean     -18.668385      0.148902    -18.584857      0.210539    -19.163124
# std        1.923275      0.596859      1.915595      1.004228      1.950311
# min      -31.461969      0.100072    -31.761922      0.100006    -32.328855
# 25%      -19.893612      0.106660    -19.830444      0.106631    -20.432413
# 50%      -19.147485      0.117924    -18.988518      0.129134    -19.501160
# 75%      -17.922848      0.139724    -17.772651      0.201996    -18.298847
# max       -5.520545     65.264145     -5.582446     86.272079     -6.235617
#
#             e_rsMag       S280Mag     e_S280Mag       W420F_E     e_W420F_E  \
# count  14283.000000  14283.000000  14283.000000  14283.000000  14283.000000
# mean       0.223603    -18.611132      0.192622      0.027612      0.003745
# std        1.005841      1.960478      0.519188      0.050961      0.001699
# min        0.100006    -27.869558      0.100193     -0.030357      0.002589
# 25%        0.112014    -19.908291      0.116232      0.010426      0.003091
# 50%        0.144694    -19.026564      0.138445      0.017516      0.003431
# 75%        0.218414    -17.776763      0.183472      0.027916      0.003923
# max       86.272079     -3.668363     35.220078      1.355057      0.050053
#
#             W462F_E     e_W462F_E       W485F_D     e_W485F_D       W518F_E  \
# count  14283.000000  14283.000000  14283.000000  14283.000000  14283.000000
# mean       0.041034      0.003473      0.036733      0.004380      0.045015
# std        0.098724      0.001080      0.098150      0.001342      0.133775
# min       -0.033697      0.002441     -0.009133      0.002867     -0.006709
# 25%        0.014858      0.002941      0.012085      0.003609      0.014369
# 50%        0.022912      0.003240      0.019210      0.004045      0.021957
# 75%        0.035898      0.003699      0.030822      0.004773      0.034934
# max        3.278790      0.038505      3.194616      0.068468      4.818458
#
#           e_W518F_E       W571F_E     e_W571F_E       W604F_E     e_W604F_E  \
# count  14283.000000  14283.000000  14283.000000  14283.000000  14283.000000
# mean       0.004226      0.056532      0.005589      0.063198      0.003966
# std        0.001485      0.166020      0.002111      0.193843      0.001715
# min        0.002806     -0.009385      0.003493     -0.004613      0.002620
# 25%        0.003508      0.017562      0.004382      0.019049      0.003272
# 50%        0.003918      0.026090      0.005023      0.027663      0.003623
# 75%        0.004533      0.043094      0.006160      0.047275      0.004215
# max        0.060376      5.443399      0.057555      6.810014      0.053542
#
#             W646F_D     e_W646F_D       W696F_E     e_W696F_E       W753F_E  \
# count  14283.000000  14283.000000  14283.000000  14283.000000  14283.000000
# mean       0.064044      0.007915      0.073702      0.003671      0.081669
# std        0.189582      0.002419      0.215692      0.001507      0.234417
# min       -0.020517      0.005293     -0.004272      0.002534     -0.008700
# 25%        0.019373      0.006476      0.021076      0.003088      0.023069
# 50%        0.029560      0.007308      0.031341      0.003403      0.035437
# 75%        0.050779      0.008687      0.058546      0.003877      0.065328
# max        6.519528      0.062139      7.025116      0.054285      7.574905
#
#           e_W753F_E       W815F_E     e_W815F_E       W856F_D     e_W856F_D  \
# count  14283.000000  14283.000000  14283.000000  14283.000000  14283.000000
# mean       0.005835      0.081894      0.007447      0.093600      0.007102
# std        0.001757      0.226712      0.002575      0.255815      0.001807
# min        0.004051     -0.048792      0.005436     -0.021631      0.004821
# 25%        0.004999      0.022117      0.006451      0.027950      0.006109
# 50%        0.005491      0.036709      0.007016      0.043575      0.006779
# 75%        0.006219      0.069797      0.007850      0.079308      0.007663
# max        0.065600      7.179773      0.159664      8.181570      0.054863
#
#             W914F_D     e_W914F_D          UF_G        e_UF_G          BF_D  \
# count  14283.000000  14283.000000  14283.000000  14283.000000  14283.000000
# mean       0.093196      0.008108      0.025709      0.003006      0.033998
# std        0.261171      0.002314      0.037537      0.000744      0.082987
# min       -0.014610      0.005809     -0.010006      0.002142     -0.003222
# 25%        0.025873      0.006969      0.010468      0.002558      0.011730
# 50%        0.041854      0.007647      0.017856      0.002825      0.018375
# 75%        0.079268      0.008647      0.028107      0.003209      0.029574
# max        8.295362      0.080945      0.881718      0.022348      2.613236
#
#              e_BF_D          VF_D        e_VF_D          RF_D        e_RF_D  \
# count  14283.000000  14283.000000  14283.000000  14283.000000  14283.000000
# mean       0.001823      0.047404      0.001736      0.067190      0.000776
# std        0.000696      0.144851      0.000838      0.203895      0.000622
# min        0.001185     -0.002703      0.001203      0.000799      0.000537
# 25%        0.001485      0.014404      0.001456      0.019037      0.000643
# 50%        0.001666      0.021272      0.001599      0.027609      0.000696
# 75%        0.001958      0.035663      0.001812      0.051726      0.000768
# max        0.021201      5.022725      0.029392      6.771044      0.024034
#
#                IF_D        e_IF_D
# count  14283.000000  14283.000000
# mean       0.085599      0.004945
# std        0.243303      0.002589
# min        0.000088      0.003372
# 25%        0.022475      0.004069
# 50%        0.037212      0.004512
# 75%        0.071960      0.005156
# max        7.837279      0.092711

# %%
# Split the data into magnitudes, magnitude errors, photon fluxes,
# photon flux errors, redshifts, and metadata
mags = pd.DataFrame([galaxies['UjMag'],galaxies['BjMag'],galaxies['VjMag'],galaxies['usMag'],
                galaxies['gsMag'],galaxies['rsMag'],galaxies['S280Mag']])
mags = mags.transpose()

Rband = pd.DataFrame([galaxies['Rmag'], galaxies['Ap_Rmag'],galaxies['e_Rmag'], galaxies['ApD_Rmag'], galaxies['mu_max']])
Rband = Rband.transpose()

magsErr = pd.DataFrame([galaxies['e_UjMag'],galaxies['e_BjMag'],galaxies['e_VjMag'],galaxies['e_usMag'],
                galaxies['e_gsMag'],galaxies['e_rsMag'],galaxies['e_S280Mag']])
magsErr = magsErr.transpose()

metadata = pd.DataFrame([galaxies['ra'],galaxies['dec'],galaxies['x'],galaxies['y']
                         ,galaxies['MC_class'],galaxies['MC_z_ml']])
metadata = metadata.transpose()

flux_filter = [col for col in galaxies if col.startswith('W') or col.startswith('UF') or col.startswith('BF')
              or col.startswith('VF') or col.startswith('RF') or col.startswith('IF')]
flux = galaxies[flux_filter]

fluxErr_filter = [col for col in galaxies if col.startswith('e_W') or col.startswith('e_UF') or col.startswith('e_BF')
              or col.startswith('e_VF') or col.startswith('e_RF') or col.startswith('e_IF')]
fluxErr = galaxies[fluxErr_filter]

redshift = pd.DataFrame([galaxies['MC_z'], galaxies['e_MC_z'],
                     galaxies['chi2red'], galaxies['e_MC_z']/galaxies['MC_z']])
redshift = redshift.transpose()
redshift.columns = ['MC_z','e_MC_z','chi2red','e_Frac_z']

# %%
#Perform EDA with a histogram and ECDF
#look at ECDFs with normal distributions for magnitudes and redshifts

#x_red, y_red = ecdf(redshift['MC_z'])
#plt.plot(x_red, y_red, marker='.', linestyle='none', label='Redshift')
#mean = np.mean(redshift['MC_z'])
#norm = np.random.normal(mean, np.std(mags[column]), 10000)
#x_norm, y_norm = ecdf(norm)
#plt.plot(x_norm, y_norm, marker='.', linestyle='none',label='Normal Dist')
#plt.title('MC_z mean = {:.4f}'.format(mean))
#plt.ylabel('ECDF')
#plt.xlabel('Magnitude')
#plt.legend()
#plt.show()

for column in mags:
    x, y = ecdf(mags[column])
    plt.plot(x, y, marker='.', linestyle='none', label=column)
    mean = np.mean(mags[column])
    norm = np.random.normal(mean, np.std(mags[column]), 10000)
    x_norm, y_norm = ecdf(norm)
    plt.plot(x_norm, y_norm, marker='.', linestyle='none', label='Normal Dist')
    plt.title('{}, mean = {:.4f}'.format(column, mean))
    #plt.axvline(mean, color ='k',linestyle='dashed', linewidth=1)
    plt.ylabel('ECDF')
    plt.xlabel('Magnitude')
    plt.legend()
    plt.show()

# %% [markdown]
# All magnitudes are close to a normal distribution, with a slightly more narrow standard deviation and fewer points on the tail ends

# %%
#correlations between high and low redshifts with magnitudes
magRedPairs = []

for column in mags:
    (r, p) = pearsonr(mags[column], redshift['MC_z'])
    if ((r>0.5) or (r<-0.5)) and (p!=1) and (r!=1):
        magRedPairs.append((column,r))
            
#plot all of these pairings
#mags['redshift'] = redshift['MC_z']
for i in range(7):
    plt.scatter(x=mags[magRedPairs[i][0]], y=redshift['MC_z'], alpha=0.2)
    mean = np.mean(mags[magRedPairs[i][0]])
    plt.axvline(mean, color ='k',linestyle='dashed', linewidth=1)
    plt.title(magRedPairs[i][0] + ' vs Redshift \n PearsonR = ' + str(magRedPairs[i][1]),
             y = 1.1)
    plt.show()

# %% [markdown]
# On many of these scatter plots, the magnitude is lower than the mean at around redshift 0.8. Test the correlation that higher redshifts correspond to a lower magnitude

# %%
low_filter = redshift['MC_z'] <=0.8
high_filter = redshift['MC_z'] > 0.8
low_red = mags[low_filter]
high_red = mags[high_filter]

# %%
def draw_bs_reds(column, low, high):
    #make arrays from the excess readmission ratios of high and low
    low_red_arr = np.array(low[column])
    high_red_arr = np.array(high[column])

    #draw bs_replicates from both samples and take their difference
    #to find the difference of the averages of these samples
    bs_replicates_l = draw_bs_reps(low_red_arr, np.mean, 10000)
    bs_replicates_h = draw_bs_reps(high_red_arr, np.mean, 10000)
    bs_replicates = bs_replicates_l - bs_replicates_h

    #calculate the confidence intervals
    conf_int = np.percentile(bs_replicates, [2.5,97.5])

    print('The mean difference in {} between small and large redshift is {:.5f}'.format(column,np.mean(bs_replicates)))
    print('95% confidence interval = {:.5f}, {:.5f}'.format(conf_int[0], conf_int[1]))

    # Plot the histogram of the replicates, the mean, and the 95% confidence interval
    plt.hist(bs_replicates, bins=50, normed=True)
    plt.axvline(np.mean(bs_replicates), color='k', linestyle='dashed', linewidth=1)
    plt.axvline(conf_int[0], color='k', linestyle='dashed', linewidth=1)
    plt.axvline(conf_int[1], color='k', linestyle='dashed', linewidth=1)

    plt.xlabel('Difference for High and Low Redshifts')
    plt.ylabel('PDF')
    plt.title(column)

    plt.show()


    #Find the p-value, assuming the null hypothesis that the difference in means is 0
    mean = np.mean(low_red_arr) - np.mean(high_red_arr)
    std = np.sqrt(np.std(low_red_arr)**2 - np.std(high_red_arr)**2)
    print(mean)
    print(np.mean(low_red_arr))
    print(np.mean(high_red_arr))
    low_shifted = low_red_arr + mean - np.mean(low_red_arr)
    high_shifted = high_red_arr + mean - np.mean(high_red_arr)

    bs_replicates_l = draw_bs_reps(low_shifted, np.mean, 10000)
    bs_replicates_h = draw_bs_reps(high_shifted, np.mean, 10000)
    bs_replicates = bs_replicates_l - bs_replicates_h

    if mean >= 0:
        p = np.sum(bs_replicates >= mean) / 10000
    else:
        p = np.sum(bs_replicates <= mean) / 10000

    print('p = ', p)
    #print('The p value of {} suggests that the null hypothesis should be rejected.'.format(p))

# %%
for column in mags:   
    draw_bs_reds(column)
# Out:
# The mean difference in UjMag between small and large redshift is 2.14808
# 95% confidence interval = 2.10425, 2.19354
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 2.1479164467271694
# -17.767277939277882
# -19.91519438600505
# p =  0.0
# The mean difference in BjMag between small and large redshift is 1.95555
# 95% confidence interval = 1.90818, 2.00206
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 1.9561134370488737
# -17.788123650925577
# -19.74423708797445
# p =  0.0
# The mean difference in VjMag between small and large redshift is 1.87875
# 95% confidence interval = 1.82894, 1.92931
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 1.8785322372044853
# -18.218440994555692
# -20.096973231760177
# p =  0.0
# The mean difference in usMag between small and large redshift is 2.14894
# 95% confidence interval = 2.10489, 2.19370
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 2.1488369857168337
# -17.919910716365525
# -20.06874770208236
# p =  0.0
# The mean difference in gsMag between small and large redshift is 1.93174
# 95% confidence interval = 1.88339, 1.97952
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 1.9317635356048939
# -17.911992557108125
# -19.84375609271302
# p =  0.0
# The mean difference in rsMag between small and large redshift is 1.83503
# 95% confidence interval = 1.78402, 1.88506
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 1.835371982750999
# -18.523834092478484
# -20.359206075229483
# p =  0.0
# The mean difference in S280Mag between small and large redshift is 2.28269
# 95% confidence interval = 2.23729, 2.32811
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 2.2829618541883754
# -17.815939413013194
# -20.09890126720157
# p =  0.0

# %%
#correlations between high and low redshifts with fluxes
fluxRedPairs = []
for column in flux:
    (r, p) = pearsonr(flux[column], redshift['MC_z'])
    fluxRedPairs.append((column,r))
    
for i in range(len(fluxRedPairs)):
    plt.scatter(x=flux[fluxRedPairs[i][0]], y=redshift['MC_z'], alpha=0.2)
    mean = np.mean(flux[fluxRedPairs[i][0]])
    plt.axvline(mean, color ='k',linestyle='dashed', linewidth=1)
    plt.title(fluxRedPairs[i][0] + ' vs Redshift \n PearsonR = ' + str(fluxRedPairs[i][1]),
             y = 1.1)
    plt.show()

# %% [markdown]
# Try below 0.4 for fluxes?

# %%
low_filter = redshift['MC_z'] <=0.4
high_filter = redshift['MC_z'] > 0.4
low_red = flux[low_filter]
high_red = flux[high_filter]

# %%
for column in flux:   
    draw_bs_reds(column, low_red, high_red)
# Out:
# The mean difference in W420F_E between small and large redshift is 0.03090
# 95% confidence interval = 0.02785, 0.03410
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.03091598744499072
# 0.050902532924184216
# 0.019986545479193495
# p =  0.0
# The mean difference in W462F_E between small and large redshift is 0.06113
# 95% confidence interval = 0.05504, 0.06757
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.06114027242078861
# 0.08709364512378653
# 0.025953372702997926
# p =  0.0
# The mean difference in W485F_D between small and large redshift is 0.06140
# 95% confidence interval = 0.05543, 0.06781
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.06131175969337703
# 0.08292219418928186
# 0.021610434495904832
# p =  0.0
# The mean difference in W518F_E between small and large redshift is 0.08225
# 95% confidence interval = 0.07403, 0.09094
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.082251180344578
# 0.1069786225492109
# 0.0247274422046329
# p =  0.0
# The mean difference in W571F_E between small and large redshift is 0.10268
# 95% confidence interval = 0.09250, 0.11358
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.10270479091959685
# 0.13390405552242565
# 0.0311992646028288
# p =  0.0
# The mean difference in W604F_E between small and large redshift is 0.11310
# 95% confidence interval = 0.10106, 0.12594
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.11312611122850169
# 0.14842099822654273
# 0.03529488699804104
# p =  0.0
# The mean difference in W646F_D between small and large redshift is 0.10441
# 95% confidence interval = 0.09267, 0.11664
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.10447682596835536
# 0.1427507666804116
# 0.038273940712056226
# p =  0.0
# The mean difference in W696F_E between small and large redshift is 0.11095
# 95% confidence interval = 0.09774, 0.12515
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.11092973224262229
# 0.15726999475830258
# 0.0463402625156803
# p =  0.0
# The mean difference in W753F_E between small and large redshift is 0.11520
# 95% confidence interval = 0.10073, 0.13010
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.1151800809224843
# 0.1684386280044394
# 0.053258547081955106
# p =  0.0
# The mean difference in W815F_E between small and large redshift is 0.10561
# 95% confidence interval = 0.09153, 0.12051
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.10574199257509734
# 0.16155401651109566
# 0.05581202393599833
# p =  0.0
# The mean difference in W856F_D between small and large redshift is 0.11572
# 95% confidence interval = 0.10034, 0.13239
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.11573989214555837
# 0.18079178748719843
# 0.06505189534164006
# p =  0.0
# The mean difference in W914F_D between small and large redshift is 0.11365
# 95% confidence interval = 0.09728, 0.13100
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.11362564364841798
# 0.17879546144781436
# 0.06516981779939637
# p =  0.0
# The mean difference in UF_G between small and large redshift is 0.02019
# 95% confidence interval = 0.01797, 0.02246
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.020203067337160013
# 0.04092882804631479
# 0.02072576070915478
# p =  0.0
# The mean difference in BF_D between small and large redshift is 0.05188
# 95% confidence interval = 0.04689, 0.05720
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.0519154152118687
# 0.07310800253894408
# 0.021192587327075373
# p =  0.0
# The mean difference in VF_D between small and large redshift is 0.08979
# 95% confidence interval = 0.08088, 0.09925
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.08980602841287395
# 0.11505886215019784
# 0.02525283373732389
# p =  0.0
# The mean difference in RF_D between small and large redshift is 0.11162
# 95% confidence interval = 0.09932, 0.12463
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.11171074708152406
# 0.1513463394635538
# 0.039635592382029745
# p =  0.0
# The mean difference in IF_D between small and large redshift is 0.10937
# 95% confidence interval = 0.09420, 0.12535
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.1093047635574663
# 0.16794312737890718
# 0.05863836382144089
# p =  0.0

# %% [markdown]
# Check different redshift ranges for fluxes and magnitudes? Like try comparing in bins of 0.2

# %%
low_filter = redshift['MC_z'] <=0.2
high_filter = (redshift['MC_z'] > 0.2) & (redshift['MC_z'] <= 0.4)
low_red = flux[low_filter]
high_red = flux[high_filter]

for column in flux:   
    draw_bs_reds(column, low_red, high_red)
# Out:
# The mean difference in W420F_E between small and large redshift is 0.02746
# 95% confidence interval = 0.02117, 0.03420
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.027447064009061953
# 0.06566613959383293
# 0.03821907558477097
# p =  0.0
# The mean difference in W462F_E between small and large redshift is 0.06599
# 95% confidence interval = 0.05315, 0.07929
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.06594334479579972
# 0.12256416410988943
# 0.05662081931408971
# p =  0.0
# The mean difference in W485F_D between small and large redshift is 0.05963
# 95% confidence interval = 0.04714, 0.07311
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.05957886590535782
# 0.11496929918237102
# 0.0553904332770132
# p =  0.0
# The mean difference in W518F_E between small and large redshift is 0.07036
# 95% confidence interval = 0.05286, 0.08877
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.07035477817188254
# 0.1448220243759828
# 0.07446724620410025
# p =  0.0
# The mean difference in W571F_E between small and large redshift is 0.06941
# 95% confidence interval = 0.04794, 0.09206
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.06948729415137339
# 0.1712808430378536
# 0.1017935488864802
# p =  0.0
# The mean difference in W604F_E between small and large redshift is 0.07524
# 95% confidence interval = 0.05019, 0.10180
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.0750932710484552
# 0.18881320618476655
# 0.11371993513631135
# p =  0.0
# The mean difference in W646F_D between small and large redshift is 0.07366
# 95% confidence interval = 0.04870, 0.09942
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.07372603236513167
# 0.182407545372414
# 0.10868151300728232
# p =  0.0
# The mean difference in W696F_E between small and large redshift is 0.08032
# 95% confidence interval = 0.05248, 0.10928
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.08046052025478206
# 0.200549213004914
# 0.12008869275013193
# p =  0.0
# The mean difference in W753F_E between small and large redshift is 0.09244
# 95% confidence interval = 0.06243, 0.12385
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.09254460379925825
# 0.2182178003574324
# 0.12567319655817416
# p =  0.0
# The mean difference in W815F_E between small and large redshift is 0.07397
# 95% confidence interval = 0.04479, 0.10445
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.07433892633245229
# 0.20154046709298526
# 0.12720154076053297
# p =  0.0
# The mean difference in W856F_D between small and large redshift is 0.08615
# 95% confidence interval = 0.05312, 0.12250
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.08597441963806102
# 0.22703689824908477
# 0.14106247861102375
# p =  0.0
# The mean difference in W914F_D between small and large redshift is 0.08468
# 95% confidence interval = 0.05077, 0.11938
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.08465711162329848
# 0.22433200034254913
# 0.13967488871925066
# p =  0.0
# The mean difference in UF_G between small and large redshift is 0.01602
# 95% confidence interval = 0.01154, 0.02073
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.015994423872046026
# 0.049532130129064496
# 0.03353770625701847
# p =  0.0
# The mean difference in BF_D between small and large redshift is 0.05125
# 95% confidence interval = 0.04075, 0.06228
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.05126521103470391
# 0.100683243785258
# 0.04941803275055409
# p =  0.0
# The mean difference in VF_D between small and large redshift is 0.06962
# 95% confidence interval = 0.05096, 0.08923
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.06976999186026896
# 0.15258771102195762
# 0.08281771916168866
# p =  0.0
# The mean difference in RF_D between small and large redshift is 0.07941
# 95% confidence interval = 0.05328, 0.10739
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.07914053494841221
# 0.19391554574434888
# 0.11477501079593667
# p =  0.0
# The mean difference in IF_D between small and large redshift is 0.08095
# 95% confidence interval = 0.04908, 0.11349
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.08107530588093381
# 0.21155303502703934
# 0.13047772914610553
# p =  0.0

# %%
low_filter = (redshift['MC_z'] <=0.4) & (redshift['MC_z'] >0.2)
high_filter = (redshift['MC_z'] > 0.4) & (redshift['MC_z'] <= 0.6)
low_red = flux[low_filter]
high_red = flux[high_filter]

for column in flux:   
    draw_bs_reds(column,low_red,high_red)
# Out:
# The mean difference in W420F_E between small and large redshift is 0.01335
# 95% confidence interval = 0.01086, 0.01593
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.013336692004484837
# 0.03821907558477097
# 0.024882383580286136
# p =  0.0
# The mean difference in W462F_E between small and large redshift is 0.02164
# 95% confidence interval = 0.01778, 0.02562
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.021653930581621406
# 0.05662081931408971
# 0.0349668887324683
# p =  0.0
# The mean difference in W485F_D between small and large redshift is 0.02498
# 95% confidence interval = 0.02083, 0.02945
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.024974490376463748
# 0.0553904332770132
# 0.030415942900549452
# p =  0.0
# The mean difference in W518F_E between small and large redshift is 0.03892
# 95% confidence interval = 0.03332, 0.04480
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.03893062220878326
# 0.07446724620410025
# 0.03553662399531699
# p =  0.0
# The mean difference in W571F_E between small and large redshift is 0.05000
# 95% confidence interval = 0.04124, 0.05906
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.05001711386439445
# 0.1017935488864802
# 0.05177643502208576
# p =  0.0
# The mean difference in W604F_E between small and large redshift is 0.05056
# 95% confidence interval = 0.04094, 0.06114
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.050530726366869255
# 0.11371993513631135
# 0.06318920876944209
# p =  0.0
# The mean difference in W646F_D between small and large redshift is 0.03925
# 95% confidence interval = 0.02980, 0.04942
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.039289767535363465
# 0.10868151300728232
# 0.06939174547191886
# p =  0.0
# The mean difference in W696F_E between small and large redshift is 0.03742
# 95% confidence interval = 0.02572, 0.05006
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.03748051853233818
# 0.12008869275013193
# 0.08260817421779375
# p =  0.0
# The mean difference in W753F_E between small and large redshift is 0.03451
# 95% confidence interval = 0.02218, 0.04766
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.034574078156035526
# 0.12567319655817416
# 0.09109911840213863
# p =  0.0
# The mean difference in W815F_E between small and large redshift is 0.03783
# 95% confidence interval = 0.02528, 0.05119
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.0377945213249814
# 0.12720154076053297
# 0.08940701943555157
# p =  0.0
# The mean difference in W856F_D between small and large redshift is 0.03926
# 95% confidence interval = 0.02572, 0.05379
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.039272700349117576
# 0.14106247861102375
# 0.10178977826190617
# p =  0.0
# The mean difference in W914F_D between small and large redshift is 0.03789
# 95% confidence interval = 0.02344, 0.05342
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.0378720120982701
# 0.13967488871925066
# 0.10180287662098056
# p =  0.0
# The mean difference in UF_G between small and large redshift is 0.00970
# 95% confidence interval = 0.00759, 0.01188
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.009698517565271639
# 0.03353770625701847
# 0.02383918869174683
# p =  0.0
# The mean difference in BF_D between small and large redshift is 0.02050
# 95% confidence interval = 0.01702, 0.02411
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.02047259506247294
# 0.04941803275055409
# 0.028945437688081152
# p =  0.0
# The mean difference in VF_D between small and large redshift is 0.04354
# 95% confidence interval = 0.03673, 0.05083
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.04351444831574614
# 0.08281771916168866
# 0.03930327084594252
# p =  0.0
# The mean difference in RF_D between small and large redshift is 0.04252
# 95% confidence interval = 0.03221, 0.05385
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.0425075099057845
# 0.11477501079593667
# 0.07226750089015217
# p =  0.0
# The mean difference in IF_D between small and large redshift is 0.03664
# 95% confidence interval = 0.02356, 0.05079
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.036645592625057344
# 0.13047772914610553
# 0.09383213652104819
# p =  0.0

# %%
low_filter = (redshift['MC_z'] <=0.6) & (redshift['MC_z'] >0.4)
high_filter = (redshift['MC_z'] > 0.6) & (redshift['MC_z'] <= 0.8)
low_red = flux[low_filter]
high_red = flux[high_filter]

for column in flux:   
    draw_bs_reds(column,low_red,high_red)
# Out:
# The mean difference in W420F_E between small and large redshift is 0.00587
# 95% confidence interval = 0.00481, 0.00695
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.0058735408525894435
# 0.024882383580286136
# 0.019008842727696693
# p =  0.0
# The mean difference in W462F_E between small and large redshift is 0.00969
# 95% confidence interval = 0.00833, 0.01110
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.009695738945159144
# 0.0349668887324683
# 0.02527114978730916
# p =  0.0
# The mean difference in W485F_D between small and large redshift is 0.00942
# 95% confidence interval = 0.00822, 0.01063
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.00941299384288493
# 0.030415942900549452
# 0.021002949057664522
# p =  0.0
# The mean difference in W518F_E between small and large redshift is 0.01074
# 95% confidence interval = 0.00940, 0.01212
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.010733423391008714
# 0.03553662399531699
# 0.024803200604308278
# p =  0.0
# The mean difference in W571F_E between small and large redshift is 0.02209
# 95% confidence interval = 0.02010, 0.02418
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.022087923944627434
# 0.05177643502208576
# 0.029688511077458325
# p =  0.0
# The mean difference in W604F_E between small and large redshift is 0.03037
# 95% confidence interval = 0.02795, 0.03287
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.03036729031063396
# 0.06318920876944209
# 0.03282191845880813
# p =  0.0
# The mean difference in W646F_D between small and large redshift is 0.03108
# 95% confidence interval = 0.02828, 0.03388
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.03106783993266176
# 0.06939174547191886
# 0.038323905539257096
# p =  0.0
# The mean difference in W696F_E between small and large redshift is 0.03123
# 95% confidence interval = 0.02762, 0.03489
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.031210496767837617
# 0.08260817421779375
# 0.05139767744995613
# p =  0.0
# The mean difference in W753F_E between small and large redshift is 0.03223
# 95% confidence interval = 0.02810, 0.03655
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.03220590725518924
# 0.09109911840213863
# 0.0588932111469494
# p =  0.0
# The mean difference in W815F_E between small and large redshift is 0.02627
# 95% confidence interval = 0.02184, 0.03088
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.026264018478090317
# 0.08940701943555157
# 0.06314300095746125
# p =  0.0
# The mean difference in W856F_D between small and large redshift is 0.03019
# 95% confidence interval = 0.02541, 0.03512
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.03019177254311413
# 0.10178977826190617
# 0.07159800571879205
# p =  0.0
# The mean difference in W914F_D between small and large redshift is 0.03204
# 95% confidence interval = 0.02695, 0.03737
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.03202159016539122
# 0.10180287662098056
# 0.06978128645558934
# p =  0.0
# The mean difference in UF_G between small and large redshift is 0.00368
# 95% confidence interval = 0.00263, 0.00472
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.003680204497323491
# 0.02383918869174683
# 0.02015898419442334
# p =  0.0
# The mean difference in BF_D between small and large redshift is 0.00849
# 95% confidence interval = 0.00731, 0.00967
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.008488068694738948
# 0.028945437688081152
# 0.020457368993342204
# p =  0.0
# The mean difference in VF_D between small and large redshift is 0.01449
# 95% confidence interval = 0.01294, 0.01601
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.014503032726476302
# 0.03930327084594252
# 0.024800238119466217
# p =  0.0
# The mean difference in RF_D between small and large redshift is 0.03117
# 95% confidence interval = 0.02825, 0.03419
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.031177726310508996
# 0.07226750089015217
# 0.041089774579643176
# p =  0.0
# The mean difference in IF_D between small and large redshift is 0.02896
# 95% confidence interval = 0.02429, 0.03361
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.028919196508295927
# 0.09383213652104819
# 0.06491294001275226
# p =  0.0

# %%
low_filter = (redshift['MC_z'] <=0.8) & (redshift['MC_z'] >0.6)
high_filter = (redshift['MC_z'] > 0.8) & (redshift['MC_z'] <= 1.2)
low_red = flux[low_filter]
high_red = flux[high_filter]

for column in flux:   
    draw_bs_reds(column, low_red, high_red)
# Out:
# The mean difference in W420F_E between small and large redshift is 0.00172
# 95% confidence interval = 0.00104, 0.00240
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.001712554276750787
# 0.019008842727696693
# 0.017296288450945906
# p =  0.0
# The mean difference in W462F_E between small and large redshift is 0.00429
# 95% confidence interval = 0.00350, 0.00506
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.004283255966880284
# 0.02527114978730916
# 0.020987893820428875
# p =  0.0
# The mean difference in W485F_D between small and large redshift is 0.00410
# 95% confidence interval = 0.00345, 0.00477
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.004108092333175554
# 0.021002949057664522
# 0.01689485672448897
# p =  0.0
# The mean difference in W518F_E between small and large redshift is 0.00601
# 95% confidence interval = 0.00531, 0.00673
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.0060099092721777915
# 0.024803200604308278
# 0.018793291332130486
# p =  0.0
# The mean difference in W571F_E between small and large redshift is 0.00758
# 95% confidence interval = 0.00677, 0.00841
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.0075777538776663905
# 0.029688511077458325
# 0.022110757199791935
# p =  0.0
# The mean difference in W604F_E between small and large redshift is 0.00931
# 95% confidence interval = 0.00839, 0.01024
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.009310674675071472
# 0.03282191845880813
# 0.023511243783736657
# p =  0.0
# The mean difference in W646F_D between small and large redshift is 0.01500
# 95% confidence interval = 0.01394, 0.01607
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.01499498087297833
# 0.038323905539257096
# 0.023328924666278766
# p =  0.0
# The mean difference in W696F_E between small and large redshift is 0.02552
# 95% confidence interval = 0.02407, 0.02701
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.02552249829166906
# 0.05139767744995613
# 0.02587517915828707
# p =  0.0
# The mean difference in W753F_E between small and large redshift is 0.02638
# 95% confidence interval = 0.02454, 0.02833
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.026367960725893404
# 0.0588932111469494
# 0.032525250421055994
# p =  0.0
# The mean difference in W815F_E between small and large redshift is 0.02649
# 95% confidence interval = 0.02435, 0.02869
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.026481137027166826
# 0.06314300095746125
# 0.03666186393029443
# p =  0.0
# The mean difference in W856F_D between small and large redshift is 0.02652
# 95% confidence interval = 0.02423, 0.02890
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.02653200744245658
# 0.07159800571879205
# 0.045065998276335464
# p =  0.0
# The mean difference in W914F_D between small and large redshift is 0.02418
# 95% confidence interval = 0.02165, 0.02674
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.024165749365089945
# 0.06978128645558934
# 0.0456155370904994
# p =  0.0
# The mean difference in UF_G between small and large redshift is 0.00133
# 95% confidence interval = 0.00066, 0.00199
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.0013250990088079194
# 0.02015898419442334
# 0.01883388518561542
# p =  0.0
# The mean difference in BF_D between small and large redshift is 0.00345
# 95% confidence interval = 0.00278, 0.00412
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.0034455581921277317
# 0.020457368993342204
# 0.017011810801214472
# p =  0.0
# The mean difference in VF_D between small and large redshift is 0.00646
# 95% confidence interval = 0.00576, 0.00717
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.006464660303654592
# 0.024800238119466217
# 0.018335577815811625
# p =  0.0
# The mean difference in RF_D between small and large redshift is 0.01792
# 95% confidence interval = 0.01675, 0.01911
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.017923230816694183
# 0.041089774579643176
# 0.023166543762948993
# p =  0.0
# The mean difference in IF_D between small and large redshift is 0.02581
# 95% confidence interval = 0.02352, 0.02817
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.025814998719076332
# 0.06491294001275226
# 0.03909794129367593
# p =  0.0

# %%
low_filter = (redshift['MC_z'] <=1.2) & (redshift['MC_z'] >0.8)
high_filter = redshift['MC_z'] > 1.2
low_red = flux[low_filter]
high_red = flux[high_filter]

for column in flux:   
    draw_bs_reds(column,high_red, low_red)
# Out:
# The mean difference in W420F_E between small and large redshift is 0.00675
# 95% confidence interval = 0.00547, 0.00808
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.006767422994360676
# 0.02406371144530658
# 0.017296288450945906
# p =  0.0
# The mean difference in W462F_E between small and large redshift is 0.00751
# 95% confidence interval = 0.00614, 0.00892
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.00751289297867639
# 0.028500786799105265
# 0.020987893820428875
# p =  0.0
# The mean difference in W485F_D between small and large redshift is 0.00618
# 95% confidence interval = 0.00502, 0.00740
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.00618836742203735
# 0.02308322414652632
# 0.01689485672448897
# p =  0.0
# The mean difference in W518F_E between small and large redshift is 0.00487
# 95% confidence interval = 0.00376, 0.00601
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.004853761191382672
# 0.023647052523513158
# 0.018793291332130486
# p =  0.0
# The mean difference in W571F_E between small and large redshift is 0.00224
# 95% confidence interval = 0.00112, 0.00337
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.0022302702913001675
# 0.024341027491092102
# 0.022110757199791935
# p =  0.0
# The mean difference in W604F_E between small and large redshift is 0.00142
# 95% confidence interval = 0.00032, 0.00259
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.0014220251521929461
# 0.024933268935929603
# 0.023511243783736657
# p =  0.0074
# The mean difference in W646F_D between small and large redshift is 0.00073
# 95% confidence interval = -0.00041, 0.00188
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.000731446081194919
# 0.024060370747473685
# 0.023328924666278766
# p =  0.1099
# The mean difference in W696F_E between small and large redshift is -0.00170
# 95% confidence interval = -0.00277, -0.00062
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# -0.0016939355848133858
# 0.024181243573473683
# 0.02587517915828707
# p =  0.0013
# The mean difference in W753F_E between small and large redshift is -0.00743
# 95% confidence interval = -0.00867, -0.00616
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# -0.007430996439205993
# 0.02509425398185
# 0.032525250421055994
# p =  0.0
# The mean difference in W815F_E between small and large redshift is -0.01222
# 95% confidence interval = -0.01365, -0.01080
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# -0.01220832073677338
# 0.024453543193521048
# 0.03666186393029443
# p =  0.0
# The mean difference in W856F_D between small and large redshift is -0.01299
# 95% confidence interval = -0.01467, -0.01129
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# -0.012990979564397313
# 0.03207501871193815
# 0.045065998276335464
# p =  0.0
# The mean difference in W914F_D between small and large redshift is -0.00679
# 95% confidence interval = -0.00887, -0.00466
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# -0.006786686816617822
# 0.038828850273881575
# 0.0456155370904994
# p =  0.0
# The mean difference in UF_G between small and large redshift is 0.00525
# 95% confidence interval = 0.00396, 0.00658
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.005241472403502999
# 0.02407535758911842
# 0.01883388518561542
# p =  0.0
# The mean difference in BF_D between small and large redshift is 0.00655
# 95% confidence interval = 0.00539, 0.00776
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.006539250980331576
# 0.023551061781546048
# 0.017011810801214472
# p =  0.0
# The mean difference in VF_D between small and large redshift is 0.00357
# 95% confidence interval = 0.00251, 0.00469
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0.0035755768789304844
# 0.02191115469474211
# 0.018335577815811625
# p =  0.0
# The mean difference in RF_D between small and large redshift is -0.00033
# 95% confidence interval = -0.00134, 0.00071
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# -0.0003229310314884701
# 0.022843612731460523
# 0.023166543762948993
# p =  0.2772
# The mean difference in IF_D between small and large redshift is -0.00987
# 95% confidence interval = -0.01142, -0.00827
# /home/maia/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# -0.009878473854912768
# 0.02921946743876316
# 0.03909794129367593
# p =  0.0

# %%
#plot confidence intervals + means for different redshift bins 
#for the same flux on top of each other?

# %%
#same process for magnitudes?
